# %%
from qm_2019_sss_3 import noblegas
import numpy as np

# %%
ng = noblegas.NobleGas('Argon',np.array([[0.0, 0.0, 0.0], [3.0, 4.0, 5.0]]))

# %%
ng.model_parameters
# Out:
# {'r_hop': 3.1810226927827516,
#  't_ss': 0.03365982238611262,
#  't_sp': -0.029154833035109226,
#  't_pp1': -0.0804163845390335,
#  't_pp2': -0.01393611496959445,
#  'r_pseudo': 2.60342991362958,
#  'v_pseudo': 0.022972992186364977,
#  'dipole': 2.781629275106456,
#  'energy_s': 3.1659446174413004,
#  'energy_p': -2.3926873325346554,
#  'coulomb_s': 0.3603533286088998,
#  'coulomb_p': -0.003267991835806299}

# %%
hf = noblegas.HartreeFock(ng)

# %%
a,b,c = hf.scf_cycle()
# Out:
# range(0, 8)
# (0,0): s, 0
# (1,1): px, 1
# (2,2): py, 1
# (3,3): pz, 1
# (4,4): s, 0
# (5,5): px, 1
# (6,6): py, 1
# (7,7): pz, 1
# [[ 5.39025169e-08 -4.18940517e-05 -5.58587356e-05 -6.98234195e-05
#   -4.14973932e-08 -8.91478583e-05 -1.18863811e-04 -1.48579764e-04]
#  [-4.18940517e-05  9.99999990e-01 -1.29366036e-08 -1.61707550e-08
#    8.91478583e-05 -7.46953067e-09 -9.95937422e-09 -1.24492180e-08]
#  [-5.58587356e-05 -1.29366036e-08  9.99999983e-01 -2.15610067e-08
#    1.18863811e-04 -9.95937439e-09 -1.32791658e-08 -1.65989572e-08]
#  [-6.98234195e-05 -1.61707550e-08 -2.15610067e-08  9.99999973e-01
#    1.48579764e-04 -1.24492179e-08 -1.65989573e-08 -2.07486966e-08]
#  [-4.14973932e-08  8.91478583e-05  1.18863811e-04  1.48579764e-04
#    5.39025169e-08  4.18940517e-05  5.58587356e-05  6.98234195e-05]
#  [-8.91478583e-05 -7.46953067e-09 -9.95937439e-09 -1.24492179e-08
#    4.18940517e-05  9.99999990e-01 -1.29366040e-08 -1.61707550e-08]
# ...
